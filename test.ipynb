# %%
from typing import Annotated, Literal
from pydantic import BaseModel, Field
from langchain_openai import ChatOpenAI
from typing import TypedDict
from langgraph.graph import START, END, StateGraph, add_messages
from langchain_groq import ChatGroq
from langchain_core.messages import BaseMessage, HumanMessage   


llm = ChatGroq(
    model="llama-3.3-70b-versatile"
)

response=llm.invoke("what is bengaluru")
print(response)

# response_metadata={'token_usage': {'completion_tokens': 459, 'prompt_tokens': 41, 'total_tokens': 500, 'completion_time': 1.102566441, 'completion_tokens_details':
# Out:
# content='Bengaluru, also known as Bangalore, is the capital city of the Indian state of Karnataka. It is located in the southern part of the country and is one of the most populous cities in India.\n\nBengaluru is a major hub for technology, innovation, and entrepreneurship, earning it the nickname "Silicon Valley of India." The city is home to many top IT companies, startups, and research institutions, and is a popular destination for young professionals and entrepreneurs.\n\nThe city has a rich cultural heritage, with a mix of traditional and modern architecture, and a vibrant arts and cultural scene. Bengaluru is also known for its pleasant climate, with mild winters and cool summers, earning it the nickname "Garden City."\n\nSome of the key attractions and features of Bengaluru include:\n\n* IT and technology industry: Bengaluru is home to many top IT companies, including Infosys, Wipro, and IBM.\n* Educational institutions: The city is home to many top universities and research institutions, including the Indian Institute of Science and the Indian Institute of Technology.\n* Cultural attractions: Bengaluru has a rich cultural scene, with many museums, galleries, and performance venues, including the National Gallery of Modern Art and the Karnataka Chitrakala Parishath.\n* Parks and gardens: The city has many beautiful parks and gardens, including the Lalbagh Botanical Garden and the Cubbon Park.\n* Food: Bengaluru is known for its diverse and vibrant food scene, with a mix of traditional South Indian cuisine and modern international restaurants.\n* Climate: Bengaluru has a pleasant climate, with mild winters and cool summers, making it a popular destination for tourists and professionals alike.\n\nOverall, Bengaluru is a vibrant and dynamic city that offers a unique blend of traditional and modern culture, technology, and innovation, making it a great place to live, work, and visit.' additional_kwargs={} response_metadata={'token_usage': {'completion_tokens': 377, 'prompt_tokens': 41, 'total_tokens': 418, 'completion_time': 1.029644169, 'completion_tokens_details': None, 'prompt_time': 0.0051964, 'prompt_tokens_details': None, 'queue_time': 0.058240369, 'total_time': 1.034840569}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_dae98b5ecb', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'} id='lc_run--019fef14-7b0c-7a42-8d80-38f427b568ba-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 41, 'output_tokens': 377, 'total_tokens': 418}
